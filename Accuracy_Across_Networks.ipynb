# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Replace these lists with your actual data
networks = ["DenseNet201", "DenseNet121", "InceptionV3", "MobileNet", "VGG19", "VGG16", "Xception"]
epochs = np.arange(1, 11)  # Assuming 10 epochs

# %%
# Training accuracy data (replace with your actual data)
training_accuracies = [
    [0.4068, 0.8842, 0.8643, 0.9203, 0.9186, 0.9239, 0.9374, 0.9406, 0.9619, 0.9546],  #Densenet201
    [0.7105, 0.8809, 0.9209, 0.9375, 0.9404, 0.9437, 0.9484, 0.9567, 0.9643, 0.9718],  #Densenet121
    [0.4662, 0.8168, 0.8953, 0.8616, 0.9192, 0.8935, 0.9104, 0.9108, 0.9043, 0.9289],  #InceptionV3
    [0.4674, 0.8268, 0.8961, 0.8763, 0.9038, 0.9114, 0.9150, 0.9248, 0.9293, 0.9430],  #MobileNet
    [0.2584, 0.6248, 0.7298, 0.7672, 0.8131, 0.8037, 0.8471, 0.8807, 0.8731, 0.8670],  #VGG19
    [0.8474, 0.8643, 0.8669, 0.9061, 0.8920, 0.9141, 0.9262, 0.9306, 0.9263, 0.9374],  #VGG16
    [0.5654, 0.8586, 0.8637, 0.9048, 0.9269, 0.8901, 0.9366, 0.9417, 0.9463, 0.9588], #Exception  
]

# %%
# Validation accuracy data (replace with your actual data)
validation_accuracies = [
    [0.8998, 0.8962, 0.9296, 0.8903, 0.9361, 0.9187, 0.9288, 0.9426, 0.9426, 0.9274], 
    [0.8751, 0.9208, 0.9346, 0.9448, 0.9441, 0.9441, 0.9463, 0.9426, 0.9601, 0.9659],
    [0.8381, 0.8976, 0.8947, 0.8925, 0.8853, 0.8954, 0.9158, 0.9346, 0.9375, 0.9448],
    [0.8308, 0.8853, 0.8758, 0.8889, 0.9332, 0.9230, 0.9194, 0.9237, 0.9361, 0.9114],
    [0.6471, 0.7204, 0.7988, 0.8155, 0.7988, 0.8678, 0.8700, 0.8787, 0.8424, 0.9005],
    [0.8700, 0.8845, 0.9034, 0.9041, 0.8954, 0.9005, 0.9259, 0.9237, 0.8911, 0.9477],
    [0.8744, 0.8693, 0.9136, 0.8729, 0.9114, 0.9303, 0.9346, 0.9230, 0.9484, 0.9593], 
        
]

# %%
# Plotting Training Accuracy
plt.figure(figsize=(10, 6))

for i in range(len(networks)):
    plt.plot(epochs, training_accuracies[i], label=f"{networks[i]} (Train)")

plt.title("Training Accuracy Across Networks")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting Validation Accuracy
plt.figure(figsize=(10, 6))

for i in range(len(networks)):
    plt.plot(epochs, validation_accuracies[i], label=f"{networks[i]} (Validation)")

plt.title("Validation Accuracy Across Networks")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()
